# %%
import pandas as pd

# %% [markdown]
# # Woking with JSON

# %%
pd.read_json('train.json').head()
# Out:
#       id      cuisine                                        ingredients
# 0  10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213       indian                [water, vegetable oil, wheat, salt]
# 4  13162       indian  [black pepper, shallots, cornflour, cayenne pe...

# %%
#  loading data using URL 
pd.read_json('http://api.exchangerate-api.com/v4/latest/INR') #url of teh data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 #  loading data using URL
# ----> 2 pd.read_json('http://api.exchangerate-api.com/v4/latest/INR')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\json\_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\json\_json.py:1025, in JsonReader.read(self)
#    1023         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1024 else:
# -> 1025     obj = self._get_object_parser(self.data)
#    1026 if self.dtype_backend is not lib.no_default:
# ...

# %% [markdown]
# # Working with SQL

# %%
pip install psycopg2-binary sqlalchemy
# Out:
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ----------- ---------------------------- 0.8/2.7 MB 6.6 MB/s eta 0:00:01
#    ------------------- -------------------- 1.3/2.7 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.4/2.7 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 4.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
user = ""
password = ""
host = ""
port = ""
dbname = ""
